# %%
# Install necessary packages (runs in the notebook environment)
# When running in Jupyter, these magic commands install missing modules into the kernel.
# %pip install -q torch torchvision torchaudio
# %pip install -q torch-geometric

import os
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch_geometric.data import Data, DataLoader
from torch_geometric.nn import GCNConv

# ============================================================
# 1. Load dataset
# ============================================================

CSV_PATH = "Battery_dataset 2.csv"   # adjust if needed
df = pd.read_csv(CSV_PATH)

print("Head:")
print(df.head())
print("\nColumns:", df.columns.tolist())

# Expected:
# ['battery_id','cycle','chI','chV','chT','disI','disV','disT','BCt','SOH','RUL']

df = df.sort_values(["battery_id", "cycle"]).reset_index(drop=True)

feature_cols = ["chI", "chV", "chT", "disI", "disV", "disT", "BCt"]
target_cols = ["SOH", "RUL"]

# ============================================================
# 2. Train / Test split at battery level
# ============================================================

batteries = df["battery_id"].unique()
train_batt, test_batt = train_test_split(batteries, test_size=0.3, random_state=42)

print("\nTrain batteries:", train_batt)
print("Test batteries:", test_batt)

df_train = df[df["battery_id"].isin(train_batt)].copy()
df_test  = df[df["battery_id"].isin(test_batt)].copy()

# ============================================================
# 3. Feature scaling
# ============================================================

scaler = StandardScaler()
df_train[feature_cols] = scaler.fit_transform(df_train[feature_cols].values)
df_test[feature_cols]  = scaler.transform(df_test[feature_cols].values)

# (optional) Save scaler for later use
import joblib
joblib.dump(scaler, "pinn_gnn_scaler.pkl")

# ============================================================
# 4. Build graphs per battery
# ============================================================

def build_graphs_from_df(df_part):
    graphs = []
    for bid, grp in df_part.groupby("battery_id"):
        grp = grp.sort_values("cycle").reset_index(drop=True)
        x = torch.tensor(grp[feature_cols].values, dtype=torch.float)    # [N, F]
        y = torch.tensor(grp[target_cols].values, dtype=torch.float)     # [N, 2]

        num_nodes = len(grp)

        # Undirected edges for GCN
        undirected_edges = []
        # Directed edges (earlier -> later) for physics
        directed_edges = []
        for i in range(num_nodes - 1):
            # undirected
            undirected_edges.append([i, i+1])
            undirected_edges.append([i+1, i])
            # directed: earlier -> later
            directed_edges.append([i, i+1])

        edge_index = torch.tensor(undirected_edges, dtype=torch.long).t().contiguous()
        edge_index_mono = torch.tensor(directed_edges, dtype=torch.long).t().contiguous()

        data = Data(x=x, edge_index=edge_index, y=y)
        data.edge_index_mono = edge_index_mono   # store separately
        data.battery_id = bid
        data.cycle = torch.tensor(grp["cycle"].values, dtype=torch.float)

        graphs.append(data)
    return graphs

train_graphs = build_graphs_from_df(df_train)
test_graphs  = build_graphs_from_df(df_test)

print(f"\nNum train graphs: {len(train_graphs)}, Num test graphs: {len(test_graphs)}")

# DataLoaders
batch_size = 4
train_loader = DataLoader(train_graphs, batch_size=batch_size, shuffle=True)
test_loader  = DataLoader(test_graphs, batch_size=1, shuffle=False)

# ============================================================
# 5. Define PINN-GNN model (multi-output: SOH & RUL)
# ============================================================

class PINNGNN(nn.Module):
    def __init__(self, in_channels, hidden_channels=64, out_channels=2):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.conv4 = GCNConv(hidden_channels, hidden_channels)
        self.conv5 = GCNConv(hidden_channels, hidden_channels)
        

        self.lin1  = nn.Linear(hidden_channels, hidden_channels)
        self.lin2  = nn.Linear(hidden_channels, out_channels)

    def forward(self, x, edge_index):
        # x: [N, F]
        # edge_index: [2, E]
        h = self.conv1(x, edge_index)
        h = F.relu(h)

        h = self.conv2(h, edge_index)
        h = F.relu(h)

        h = self.conv3(h, edge_index)
        h = F.relu(h)

        h = self.conv4(h, edge_index)
        h = F.relu(h)
        
        h = self.conv5(h, edge_index)
        h = F.relu(h)


        h = self.lin1(h)
        h = F.relu(h)

        out = self.lin2(h)   # [N, 2] -> SOH, RUL
        return out

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = PINNGNN(in_channels=len(feature_cols)).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# ============================================================
# 6. Physics-informed loss components
# ============================================================

def rmse_torch(y_true, y_pred):
    return torch.sqrt(F.mse_loss(y_pred, y_true))

def physics_losses(pred, edge_index_mono, edge_index_smooth):
    """
    pred: [N, 2]
    edge_index_mono: [2, E_m] earlier -> later
    edge_index_smooth: [2, E_s] undirected for smoothness
    """
    soh_pred = pred[:, 0]
    rul_pred = pred[:, 1]  # not used yet, but kept for future physics

    # ---- Monotonicity (SOH at later cycle <= earlier cycle) ----
    src_m = edge_index_mono[0]
    dst_m = edge_index_mono[1]

    soh_diff = soh_pred[dst_m] - soh_pred[src_m]  # later - earlier
    mono_violation = torch.clamp(soh_diff, min=0.0)
    mono_loss = (mono_violation ** 2).mean()

    # ---- Smoothness (use undirected edges) ----
    src_s = edge_index_smooth[0]
    dst_s = edge_index_smooth[1]

    diff_vec = pred[dst_s] - pred[src_s]   # [E_s, 2]
    smooth_loss = (diff_vec ** 2).mean()

    return mono_loss, smooth_loss

lambda_mono = 1.0
lambda_smooth = 0.1

# ============================================================
# 7. Training loop
# ============================================================

def train_one_epoch():
    model.train()
    total_loss = 0.0
    total_rmse_soh = 0.0
    total_rmse_rul = 0.0
    count = 0

    for batch in train_loader:
        batch = batch.to(device)
        optimizer.zero_grad()

        out = model(batch.x, batch.edge_index)   # [total_nodes_in_batch, 2]
        y_true = batch.y                         # same shape

        # Supervised loss
        loss_sup = F.mse_loss(out, y_true)

        # Physics-informed losses
        # FIXED: pass both edge_index_mono and edge_index
        mono_loss, smooth_loss = physics_losses(
            out,
            batch.edge_index_mono,
            batch.edge_index
        )

        loss = loss_sup + lambda_mono * mono_loss + lambda_smooth * smooth_loss
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        # RMSE for logging (on batch)
        soh_true = y_true[:, 0]
        rul_true = y_true[:, 1]
        soh_pred = out[:, 0]
        rul_pred = out[:, 1]
        total_rmse_soh += rmse_torch(soh_true, soh_pred).item()
        total_rmse_rul += rmse_torch(rul_true, rul_pred).item()
        count += 1

    return total_loss / count, total_rmse_soh / count, total_rmse_rul / count

@torch.no_grad()
def eval_loader(loader):
    model.eval()
    all_true_soh, all_pred_soh = [], []
    all_true_rul, all_pred_rul = [], []

    for batch in loader:
        batch = batch.to(device)
        out = model(batch.x, batch.edge_index)
        y_true = batch.y

        all_true_soh.append(y_true[:, 0].cpu().numpy())
        all_true_rul.append(y_true[:, 1].cpu().numpy())
        all_pred_soh.append(out[:, 0].cpu().numpy())
        all_pred_rul.append(out[:, 1].cpu().numpy())

    all_true_soh = np.concatenate(all_true_soh)
    all_pred_soh = np.concatenate(all_pred_soh)
    all_true_rul = np.concatenate(all_true_rul)
    all_pred_rul = np.concatenate(all_pred_rul)

    rmse_soh = np.sqrt(mean_squared_error(all_true_soh, all_pred_soh))
    rmse_rul = np.sqrt(mean_squared_error(all_true_rul, all_pred_rul))

    return rmse_soh, rmse_rul, (all_true_soh, all_pred_soh, all_true_rul, all_pred_rul)

num_epochs = 80
best_rmse_soh = float("inf")
best_state = None

for epoch in range(1, num_epochs + 1):
    train_loss, train_rmse_soh, train_rmse_rul = train_one_epoch()
    test_rmse_soh, test_rmse_rul, _ = eval_loader(test_loader)

    print(f"Epoch {epoch:03d} | "
          f"TrainLoss={train_loss:.5f} | "
          f"TrainRMSE(SOH)={train_rmse_soh:.5f} | TrainRMSE(RUL)={train_rmse_rul:.5f} | "
          f"TestRMSE(SOH)={test_rmse_soh:.5f} | TestRMSE(RUL)={test_rmse_rul:.5f}")

    if test_rmse_soh < best_rmse_soh:
        best_rmse_soh = test_rmse_soh
        best_state = model.state_dict()

# Load best state
if best_state is not None:
    model.load_state_dict(best_state)
    print("\nLoaded best model based on SOH RMSE.")

# Final evaluation
test_rmse_soh, test_rmse_rul, (true_soh, pred_soh, true_rul, pred_rul) = eval_loader(test_loader)
print("\n=== FINAL TEST PERFORMANCE (PINN-GNN) ===")
print(f"SOH RMSE : {test_rmse_soh:.6f}")
print(f"RUL RMSE : {test_rmse_rul:.6f}")

# ============================================================
# 8. Save model
# ============================================================

MODEL_PATH = "pinn_gnn_model.pt"
torch.save(model.state_dict(), MODEL_PATH)
print(f"\nSaved PINN-GNN model to: {os.path.abspath(MODEL_PATH)}")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Head:
#   battery_id  cycle       chI       chV        chT      disI      disV  \
# 0         B5      1  1.440147  4.254682  23.988733  1.894407  3.273523
# 1         B5      2  1.416595  4.159825  25.665347  1.829949  4.038741
# 2         B5      3  1.420272  4.276323  25.407910  1.942105  3.214433
# 3         B5      4  1.337680  4.236697  27.069757  2.073577  3.134529
# 4         B5      5  1.263946  4.142791  26.478353  2.049885  3.729341
#
#         disT       BCt        SOH  RUL
# 0  32.980834  1.986196  99.309790  219
# 1  32.257920  1.986240  99.311985  218
# 2  35.134801  1.984252  99.212608  217
# 3  32.082988  1.969236  98.461812  216
# 4  32.483154  1.974862  98.743106  215
#
# Columns: ['battery_id', 'cycle', 'chI', 'chV', 'chT', 'disI', 'disV', 'disT', 'BCt', 'SOH', 'RUL']
#
# Train batteries: ['B6' 'B7']
# Test batteries: ['B5']
#
# Num train graphs: 2, Num test graphs: 1
# Epoch 001 | TrainLoss=11610.41895 | TrainRMSE(SOH)=72.98877 | TrainRMSE(RUL)=133.76649 | TestRMSE(SOH)=74.16024 | TestRMSE(RUL)=126.48458
# Epoch 002 | TrainLoss=11608.53418 | TrainRMSE(SOH)=72.97924 | TrainRMSE(RUL)=133.75761 | TestRMSE(SOH)=74.15021 | TestRMSE(RUL)=126.47567
# Epoch 003 | TrainLoss=11606.63379 | TrainRMSE(SOH)=72.96925 | TrainRMSE(RUL)=133.74886 | TestRMSE(SOH)=74.13934 | TestRMSE(RUL)=126.46672
# Epoch 004 | TrainLoss=11604.66699 | TrainRMSE(SOH)=72.95842 | TrainRMSE(RUL)=133.74007 | TestRMSE(SOH)=74.12782 | TestRMSE(RUL)=126.45786
# Epoch 005 | TrainLoss=11602.65234 | TrainRMSE(SOH)=72.94686 | TrainRMSE(RUL)=133.73129 | TestRMSE(SOH)=74.11536 | TestRMSE(RUL)=126.44889
# Epoch 006 | TrainLoss=11600.56348 | TrainRMSE(SOH)=72.93445 | TrainRMSE(RUL)=133.72244 | TestRMSE(SOH)=74.10166 | TestRMSE(RUL)=126.43946
# Epoch 007 | TrainLoss=11598.33496 | TrainRMSE(SOH)=72.92088 | TrainRMSE(RUL)=133.71318 | TestRMSE(SOH)=74.08675 | TestRMSE(RUL)=126.42937
# Epoch 008 | TrainLoss=11595.91309 | TrainRMSE(SOH)=72.90597 | TrainRMSE(RUL)=133.70320 | TestRMSE(SOH)=74.07044 | TestRMSE(RUL)=126.41833
# Epoch 009 | TrainLoss=11593.24121 | TrainRMSE(SOH)=72.88955 | TrainRMSE(RUL)=133.69217 | TestRMSE(SOH)=74.05251 | TestRMSE(RUL)=126.40596
# Epoch 010 | TrainLoss=11590.25684 | TrainRMSE(SOH)=72.87151 | TrainRMSE(RUL)=133.67967 | TestRMSE(SOH)=74.03269 | TestRMSE(RUL)=126.39180
# Epoch 011 | TrainLoss=11586.88867 | TrainRMSE(SOH)=72.85143 | TrainRMSE(RUL)=133.66544 | TestRMSE(SOH)=74.01028 | TestRMSE(RUL)=126.37549
# Epoch 012 | TrainLoss=11583.05859 | TrainRMSE(SOH)=72.82877 | TrainRMSE(RUL)=133.64912 | TestRMSE(SOH)=73.98431 | TestRMSE(RUL)=126.35691
# Epoch 013 | TrainLoss=11578.68652 | TrainRMSE(SOH)=72.80270 | TrainRMSE(RUL)=133.63062 | TestRMSE(SOH)=73.95380 | TestRMSE(RUL)=126.33604
# Epoch 014 | TrainLoss=11573.66699 | TrainRMSE(SOH)=72.77203 | TrainRMSE(RUL)=133.60976 | TestRMSE(SOH)=73.91764 | TestRMSE(RUL)=126.31201
# Epoch 015 | TrainLoss=11567.80664 | TrainRMSE(SOH)=72.73552 | TrainRMSE(RUL)=133.58577 | TestRMSE(SOH)=73.87426 | TestRMSE(RUL)=126.28326
# Epoch 016 | TrainLoss=11560.80762 | TrainRMSE(SOH)=72.69183 | TrainRMSE(RUL)=133.55716 | TestRMSE(SOH)=73.82210 | TestRMSE(RUL)=126.24836
# Epoch 017 | TrainLoss=11552.39453 | TrainRMSE(SOH)=72.63959 | TrainRMSE(RUL)=133.52258 | TestRMSE(SOH)=73.75989 | TestRMSE(RUL)=126.20633
# Epoch 018 | TrainLoss=11542.30859 | TrainRMSE(SOH)=72.57729 | TrainRMSE(RUL)=133.48091 | TestRMSE(SOH)=73.68613 | TestRMSE(RUL)=126.15595
# Epoch 019 | TrainLoss=11530.27246 | TrainRMSE(SOH)=72.50331 | TrainRMSE(RUL)=133.43094 | TestRMSE(SOH)=73.59864 | TestRMSE(RUL)=126.09556
# Epoch 020 | TrainLoss=11515.93457 | TrainRMSE(SOH)=72.41563 | TrainRMSE(RUL)=133.37108 | TestRMSE(SOH)=73.49493 | TestRMSE(RUL)=126.02333
# Epoch 021 | TrainLoss=11498.87207 | TrainRMSE(SOH)=72.31173 | TrainRMSE(RUL)=133.29948 | TestRMSE(SOH)=73.37206 | TestRMSE(RUL)=125.93700
# /var/folders/5r/_xy1410s2v79gzphw2rfltyh0000gn/T/ipykernel_2546/3119229096.py:107: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   train_loader = DataLoader(train_graphs, batch_size=batch_size, shuffle=True)
# /var/folders/5r/_xy1410s2v79gzphw2rfltyh0000gn/T/ipykernel_2546/3119229096.py:108: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   test_loader  = DataLoader(test_graphs, batch_size=1, shuffle=False)
# Epoch 022 | TrainLoss=11478.58008 | TrainRMSE(SOH)=72.18861 | TrainRMSE(RUL)=133.21397 | TestRMSE(SOH)=73.22641 | TestRMSE(RUL)=125.83380
# Epoch 023 | TrainLoss=11454.48145 | TrainRMSE(SOH)=72.04282 | TrainRMSE(RUL)=133.11195 | TestRMSE(SOH)=73.05445 | TestRMSE(RUL)=125.71004
# Epoch 024 | TrainLoss=11425.89746 | TrainRMSE(SOH)=71.87071 | TrainRMSE(RUL)=132.99019 | TestRMSE(SOH)=72.85189 | TestRMSE(RUL)=125.56163
# Epoch 025 | TrainLoss=11391.98438 | TrainRMSE(SOH)=71.66848 | TrainRMSE(RUL)=132.84424 | TestRMSE(SOH)=72.61346 | TestRMSE(RUL)=125.38388
# Epoch 026 | TrainLoss=11351.80859 | TrainRMSE(SOH)=71.43067 | TrainRMSE(RUL)=132.66977 | TestRMSE(SOH)=72.33268 | TestRMSE(RUL)=125.17164
# Epoch 027 | TrainLoss=11304.30762 | TrainRMSE(SOH)=71.15105 | TrainRMSE(RUL)=132.46182 | TestRMSE(SOH)=72.00053 | TestRMSE(RUL)=124.91908
# Epoch 028 | TrainLoss=11248.14453 | TrainRMSE(SOH)=70.82057 | TrainRMSE(RUL)=132.21468 | TestRMSE(SOH)=71.60679 | TestRMSE(RUL)=124.61845
# Epoch 029 | TrainLoss=11181.68457 | TrainRMSE(SOH)=70.42932 | TrainRMSE(RUL)=131.92064 | TestRMSE(SOH)=71.14054 | TestRMSE(RUL)=124.26048
# Epoch 030 | TrainLoss=11103.12695 | TrainRMSE(SOH)=69.96660 | TrainRMSE(RUL)=131.57089 | TestRMSE(SOH)=70.58927 | TestRMSE(RUL)=123.83478
# Epoch 031 | TrainLoss=11010.48438 | TrainRMSE(SOH)=69.42014 | TrainRMSE(RUL)=131.15553 | TestRMSE(SOH)=69.93868 | TestRMSE(RUL)=123.32976
# Epoch 032 | TrainLoss=10901.47363 | TrainRMSE(SOH)=68.77553 | TrainRMSE(RUL)=130.66299 | TestRMSE(SOH)=69.17175 | TestRMSE(RUL)=122.73166
# Epoch 033 | TrainLoss=10773.51855 | TrainRMSE(SOH)=68.01598 | TrainRMSE(RUL)=130.07993 | TestRMSE(SOH)=68.26884 | TestRMSE(RUL)=122.02456
# Epoch 034 | TrainLoss=10623.73730 | TrainRMSE(SOH)=67.12215 | TrainRMSE(RUL)=129.39081 | TestRMSE(SOH)=67.20721 | TestRMSE(RUL)=121.19006
# Epoch 035 | TrainLoss=10448.96289 | TrainRMSE(SOH)=66.07191 | TrainRMSE(RUL)=128.57788 | TestRMSE(SOH)=65.96049 | TestRMSE(RUL)=120.20682
# Epoch 036 | TrainLoss=10245.79492 | TrainRMSE(SOH)=64.84014 | TrainRMSE(RUL)=127.62103 | TestRMSE(SOH)=64.49864 | TestRMSE(RUL)=119.05055
# Epoch 037 | TrainLoss=10010.51270 | TrainRMSE(SOH)=63.39773 | TrainRMSE(RUL)=126.49686 | TestRMSE(SOH)=62.78750 | TestRMSE(RUL)=117.69372
# Epoch 038 | TrainLoss=9739.22266 | TrainRMSE(SOH)=61.71129 | TrainRMSE(RUL)=125.17887 | TestRMSE(SOH)=60.78714 | TestRMSE(RUL)=116.10434
# Epoch 039 | TrainLoss=9427.91699 | TrainRMSE(SOH)=59.74292 | TrainRMSE(RUL)=123.63675 | TestRMSE(SOH)=58.45277 | TestRMSE(RUL)=114.24680
# Epoch 040 | TrainLoss=9072.77344 | TrainRMSE(SOH)=57.45061 | TrainRMSE(RUL)=121.83673 | TestRMSE(SOH)=55.73498 | TestRMSE(RUL)=112.08210
# Epoch 041 | TrainLoss=8670.34668 | TrainRMSE(SOH)=54.78786 | TrainRMSE(RUL)=119.74096 | TestRMSE(SOH)=52.57808 | TestRMSE(RUL)=109.56579
# Epoch 042 | TrainLoss=8218.13477 | TrainRMSE(SOH)=51.70547 | TrainRMSE(RUL)=117.30867 | TestRMSE(SOH)=48.92280 | TestRMSE(RUL)=106.65012
# Epoch 043 | TrainLoss=7715.01562 | TrainRMSE(SOH)=48.15303 | TrainRMSE(RUL)=114.49576 | TestRMSE(SOH)=44.70877 | TestRMSE(RUL)=103.28510
# Epoch 044 | TrainLoss=7162.22998 | TrainRMSE(SOH)=44.08602 | TrainRMSE(RUL)=111.25690 | TestRMSE(SOH)=39.88235 | TestRMSE(RUL)=99.41934
# Epoch 045 | TrainLoss=6564.49561 | TrainRMSE(SOH)=39.47933 | TrainRMSE(RUL)=107.54805 | TestRMSE(SOH)=34.42397 | TestRMSE(RUL)=95.01090
# Epoch 046 | TrainLoss=5931.63574 | TrainRMSE(SOH)=34.35903 | TrainRMSE(RUL)=103.33237 | TestRMSE(SOH)=28.40043 | TestRMSE(RUL)=90.03092
# Epoch 047 | TrainLoss=5280.49658 | TrainRMSE(SOH)=28.88481 | TrainRMSE(RUL)=98.58852 | TestRMSE(SOH)=22.15078 | TestRMSE(RUL)=84.48264
# Epoch 048 | TrainLoss=4637.71729 | TrainRMSE(SOH)=23.57403 | TrainRMSE(RUL)=93.32914 | TestRMSE(SOH)=16.89605 | TestRMSE(RUL)=78.44100
# Epoch 049 | TrainLoss=4041.57935 | TrainRMSE(SOH)=19.80770 | TrainRMSE(RUL)=87.62587 | TestRMSE(SOH)=15.78062 | TestRMSE(RUL)=72.09132
# Epoch 050 | TrainLoss=3541.05396 | TrainRMSE(SOH)=19.99716 | TrainRMSE(RUL)=81.64375 | TestRMSE(SOH)=20.83516 | TestRMSE(RUL)=65.79033
# Epoch 051 | TrainLoss=3187.77319 | TrainRMSE(SOH)=25.02471 | TrainRMSE(RUL)=75.68324 | TestRMSE(SOH)=29.19520 | TestRMSE(RUL)=60.09909
# Epoch 052 | TrainLoss=3014.53320 | TrainRMSE(SOH)=32.79495 | TrainRMSE(RUL)=70.19134 | TestRMSE(SOH)=37.82634 | TestRMSE(RUL)=55.66339
# Epoch 053 | TrainLoss=3006.11548 | TrainRMSE(SOH)=40.83591 | TrainRMSE(RUL)=65.67098 | TestRMSE(SOH)=44.82312 | TestRMSE(RUL)=52.81950
# Epoch 054 | TrainLoss=3084.62817 | TrainRMSE(SOH)=47.32236 | TrainRMSE(RUL)=62.39904 | TestRMSE(SOH)=49.04634 | TestRMSE(RUL)=51.21540
# Epoch 055 | TrainLoss=3135.08179 | TrainRMSE(SOH)=51.11708 | TrainRMSE(RUL)=60.15440 | TestRMSE(SOH)=50.15976 | TestRMSE(RUL)=50.06124
# Epoch 056 | TrainLoss=3069.43335 | TrainRMSE(SOH)=51.87829 | TrainRMSE(RUL)=58.38207 | TestRMSE(SOH)=48.49648 | TestRMSE(RUL)=48.73758
# Epoch 057 | TrainLoss=2869.32202 | TrainRMSE(SOH)=49.93199 | TrainRMSE(RUL)=56.63745 | TestRMSE(SOH)=44.73178 | TestRMSE(RUL)=47.06228
# Epoch 058 | TrainLoss=2574.07715 | TrainRMSE(SOH)=45.94221 | TrainRMSE(RUL)=54.79492 | TestRMSE(SOH)=39.61736 | TestRMSE(RUL)=45.18131
# Epoch 059 | TrainLoss=2245.38110 | TrainRMSE(SOH)=40.64971 | TrainRMSE(RUL)=52.97829 | TestRMSE(SOH)=33.85506 | TestRMSE(RUL)=43.36840
# Epoch 060 | TrainLoss=1938.31458 | TrainRMSE(SOH)=34.74424 | TrainRMSE(RUL)=51.39362 | TestRMSE(SOH)=28.04469 | TestRMSE(RUL)=41.85396
# Epoch 061 | TrainLoss=1686.76697 | TrainRMSE(SOH)=28.81215 | TrainRMSE(RUL)=50.18538 | TestRMSE(SOH)=22.67355 | TestRMSE(RUL)=40.73101
# Epoch 062 | TrainLoss=1501.29211 | TrainRMSE(SOH)=23.32136 | TrainRMSE(RUL)=49.36449 | TestRMSE(SOH)=18.12156 | TestRMSE(RUL)=39.93613
# Epoch 063 | TrainLoss=1375.03528 | TrainRMSE(SOH)=18.63357 | TrainRMSE(RUL)=48.82139 | TestRMSE(SOH)=14.66741 | TestRMSE(RUL)=39.30680
# Epoch 064 | TrainLoss=1291.35547 | TrainRMSE(SOH)=15.00756 | TrainRMSE(RUL)=48.37551 | TestRMSE(SOH)=12.45323 | TestRMSE(RUL)=38.65318
# Epoch 065 | TrainLoss=1231.28821 | TrainRMSE(SOH)=12.57867 | TrainRMSE(RUL)=47.83983 | TestRMSE(SOH)=11.39521 | TestRMSE(RUL)=37.81586
# Epoch 066 | TrainLoss=1178.55127 | TrainRMSE(SOH)=11.29127 | TrainRMSE(RUL)=47.06482 | TestRMSE(SOH)=11.16990 | TestRMSE(RUL)=36.69370
# Epoch 067 | TrainLoss=1122.04797 | TrainRMSE(SOH)=10.86825 | TrainRMSE(RUL)=45.95987 | TestRMSE(SOH)=11.38487 | TestRMSE(RUL)=35.25694
# Epoch 068 | TrainLoss=1056.19409 | TrainRMSE(SOH)=10.94168 | TrainRMSE(RUL)=44.49215 | TestRMSE(SOH)=11.76112 | TestRMSE(RUL)=33.54262
# Epoch 069 | TrainLoss=980.39868 | TrainRMSE(SOH)=11.22593 | TrainRMSE(RUL)=42.68447 | TestRMSE(SOH)=12.16755 | TestRMSE(RUL)=31.65523
# Epoch 070 | TrainLoss=898.08215 | TrainRMSE(SOH)=11.57534 | TrainRMSE(RUL)=40.61357 | TestRMSE(SOH)=12.57656 | TestRMSE(RUL)=29.76769
# Epoch 071 | TrainLoss=815.44177 | TrainRMSE(SOH)=11.95341 | TrainRMSE(RUL)=38.40850 | TestRMSE(SOH)=13.01201 | TestRMSE(RUL)=28.11048
# Epoch 072 | TrainLoss=739.88281 | TrainRMSE(SOH)=12.37786 | TrainRMSE(RUL)=36.24306 | TestRMSE(SOH)=13.50668 | TestRMSE(RUL)=26.93406
# Epoch 073 | TrainLoss=678.38409 | TrainRMSE(SOH)=12.87590 | TrainRMSE(RUL)=34.31739 | TestRMSE(SOH)=14.07101 | TestRMSE(RUL)=26.42285
# Epoch 074 | TrainLoss=635.80249 | TrainRMSE(SOH)=13.45357 | TrainRMSE(RUL)=32.81708 | TestRMSE(SOH)=14.67770 | TestRMSE(RUL)=26.59847
# Epoch 075 | TrainLoss=613.29492 | TrainRMSE(SOH)=14.07847 | TrainRMSE(RUL)=31.84954 | TestRMSE(SOH)=15.26522 | TestRMSE(RUL)=27.27568
# Epoch 076 | TrainLoss=607.43823 | TrainRMSE(SOH)=14.68491 | TrainRMSE(RUL)=31.38383 | TestRMSE(SOH)=15.75994 | TestRMSE(RUL)=28.12636
# Epoch 077 | TrainLoss=610.99554 | TrainRMSE(SOH)=15.19663 | TrainRMSE(RUL)=31.25037 | TestRMSE(SOH)=16.10734 | TestRMSE(RUL)=28.80331
# Epoch 078 | TrainLoss=615.15411 | TrainRMSE(SOH)=15.55525 | TrainRMSE(RUL)=31.20640 | TestRMSE(SOH)=16.29498 | TestRMSE(RUL)=29.04863
# Epoch 079 | TrainLoss=612.79425 | TrainRMSE(SOH)=15.74825 | TrainRMSE(RUL)=31.03561 | TestRMSE(SOH)=16.36226 | TestRMSE(RUL)=28.74774
# Epoch 080 | TrainLoss=601.04694 | TrainRMSE(SOH)=15.81666 | TrainRMSE(RUL)=30.62424 | TestRMSE(SOH)=16.38898 | TestRMSE(RUL)=27.93032
#
# Loaded best model based on SOH RMSE.
#
# === FINAL TEST PERFORMANCE (PINN-GNN) ===
# SOH RMSE : 16.388976
# RUL RMSE : 27.930319
#
# Saved PINN-GNN model to: /Users/uditbhardwaj/Documents/AndroidProjects/Lithium-ion-batteryNASA/pinn_gnn_model.pt

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

def mae(y_true, y_pred):
    return mean_absolute_error(y_true, y_pred)

def mape(y_true, y_pred, eps=1e-6):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    return np.mean(np.abs((y_pred - y_true) / (y_true + eps))) * 100

def nrmse(y_true, y_pred):
    return rmse(y_true, y_pred) / (np.max(y_true) - np.min(y_true))

def accuracy_from_mape(mape_value):
    """Converts regression to accuracy-like score."""
    return (1 - (mape_value / 100)) * 100

def print_metrics(title, y_true, y_pred):
    print(f"\n===== {title} =====")
    r = rmse(y_true, y_pred)
    a = mae(y_true, y_pred)
    m = mape(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    nr = nrmse(y_true, y_pred)
    acc = accuracy_from_mape(m)

    print(f"RMSE      : {r:.6f}")
    print(f"MAE       : {a:.6f}")
    print(f"MAPE      : {m:.4f}%")
    print(f"R² Score  : {r2:.6f}")
    print(f"NRMSE     : {nr:.6f}")
    print(f"Accuracy* : {acc:.3f}%   (1 - MAPE)")

# %%
print("\n\n==================== FINAL PINN-GNN METRICS ====================")

print_metrics("SOH (State of Health)", true_soh, pred_soh)
print_metrics("RUL (Remaining Useful Life)", true_rul, pred_rul)

print("\n===============================================================")
# Out:
# ==================== FINAL PINN-GNN METRICS ====================
#
# ===== SOH (State of Health) =====
# RMSE      : 16.388976
# MAE       : 14.941216
# MAPE      : 21.6187%
# R² Score  : -0.066427
# NRMSE     : 0.301274
# Accuracy* : 78.381%   (1 - MAPE)
#
# ===== RUL (Remaining Useful Life) =====
# RMSE      : 27.930319
# MAE       : 22.790058
# MAPE      : 27105171.8750%
# R² Score  : 0.806582
# NRMSE     : 0.127536
# Accuracy* : -27105071.875%   (1 - MAPE)
#
# ===============================================================
